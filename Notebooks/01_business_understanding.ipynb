# %% [markdown]
# # Proyecto Final
# # Sistema Inteligente de Recomendación para E-commerce
#
# ## Integrantes
#
# - Yustin Rodríguez
# - Elías
# - Carina
# - Rocío
#
# ## Objetivo
#
# Comprender el problema de negocio, conocer la estructura del dataset y preparar el entorno para el desarrollo del sistema de recomendación.

# %% [markdown]
# # Contexto del negocio
#
# El objetivo del proyecto es desarrollar un sistema de recomendación de productos
# para una plataforma de comercio electrónico utilizando información histórica de
# clientes, productos, órdenes y eventos de navegación.
